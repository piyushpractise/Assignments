# %% [markdown]
# # Statistics Advance-3

# %% [markdown]
# #### Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# * Estimation Statistics: It involves using sample data to make inferences or predictions about a population.
# * Point Estimate: It's a single value (such as the sample mean) that serves as an estimate of a population parameter.
# * Interval Estimate: It's a range of values (confidence interval) within which the true population parameter is likely to fall.

# %% [markdown]
# #### Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
def estimate_pop_mean(sample_mean, sample_std_dev, sample_size):
    estimated_mean = sample_mean
    return estimated_mean
sample_mean = 50
sample_std_dev = 10
sample_size = 100
pop_mean_estimate = estimate_pop_mean(sample_mean, sample_std_dev, sample_size)
print("Estimated Population Mean:", pop_mean_estimate)
# Out:
# Estimated Population Mean: 50

# %% [markdown]
# #### Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# * Hypothesis Testing: It's a statistical method to make decisions about population parameters based on sample data.
# * Importance: It helps us determine if an observed effect in data is statistically significant or likely due to chance. It provides a structured framework for making informed decisions based on data.

# %% [markdown]
# #### Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# * Hypothesis: Null hypothesis (H0): The average weight of male college students is equal to or less than the average weight of female college students.
# * Alternative hypothesis (Ha): The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# #### Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import scipy.stats as stats
def two_sample_t_test(sample1, sample2, alpha):
    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    if p_value < alpha:
        return "Reject Null Hypothesis"
    else:
        return "Fail to Reject Null Hypothesis"
sample1 = [82, 78, 85, 89, 90]
sample2 = [76, 72, 80, 81, 79]
alpha = 0.05
result = two_sample_t_test(sample1, sample2, alpha)
print(result)
# Out:
# Reject Null Hypothesis

# %% [markdown]
# #### Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# * Null Hypothesis (H0): It's a statement of no effect or no difference. Examples: The mean weight of product A is equal to the mean weight of product B.
# * Alternative Hypothesis (Ha): It's a statement that contradicts the null hypothesis. Examples: The mean weight of product A is not equal to the mean weight of product B.

# %% [markdown]
# #### Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# 1. Formulate null (H0) and alternative (Ha) hypotheses.
# 2. Choose a significance level (alpha).
# 3. Collect sample data and calculate test statistic.
# 4. Calculate p-value.
# 5. Compare p-value with alpha:
#     * If p-value < alpha, reject H0.
#     * If p-value >= alpha, fail to reject H0.

# %% [markdown]
# #### Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# * p-value: It's the probability of obtaining a test statistic as extreme as or more extreme than the observed, assuming the null hypothesis is true.
# * Significance: A small p-value (typically ≤ 0.05) suggests that the observed effect is unlikely due to chance, leading to the rejection of the null hypothesis.

# %% [markdown]
# #### Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as pt
degrees_of_freedom = 10
x = np.linspace(-4, 4, 500)
y = stats.t.pdf(x, degrees_of_freedom)
pt.plot(x, y)
pt.title("Student's t-Distribution (df=10)")
pt.xlabel("x")
pt.ylabel("Probability Density")
pt.show()

# %% [markdown]
# #### Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
def two_sample_t_test_independent(sample1, sample2):
    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    return t_stat, p_value
sample1 = [82, 78, 85, 89, 90]
sample2 = [76, 72, 80, 81, 79]
t_statistic, p_value = two_sample_t_test_independent(sample1, sample2)
print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 2.6117145003960434
# p-value: 0.031047494841772112

# %% [markdown]
# #### Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# * t-Distribution: It's a probability distribution used for making inferences about population means when the sample size is small or the population standard deviation is unknown. It resembles the normal distribution but has fatter tails.
# * Use: It's used in situations where the sample size is small or the population standard deviation is unknown, making the normal distribution inappropriate.

# %% [markdown]
# #### Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# * t-statistic: It's a measure that quantifies the difference between a sample estimate and a population parameter in terms of the standard error.
# * Formula: t = (sample mean - population mean) / (sample standard deviation / √sample size)

# %% [markdown]
# #### Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be 500 dollar with a standard deviation of 50 dollar. Estimate the population mean revenue with a 95% confidence interval.

# %% [markdown]
# * 95% Confidence Interval: $500 ± Margin of Error
#
# * Margin of Error: z*(sample standard deviation / √sample size)
#
# * Using z-score for 95% confidence interval: z = 1.96
#
# * Calculation: Margin of Error = 1.96*($50 / √50) ≈ $13.89
#
# * Confidence Interval: $500 ± $13.89
#
# * Result: Population mean revenue is estimated to be between $486.11 and $513.89.

# %% [markdown]
# #### Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# * Null Hypothesis (H0): The drug has no effect (μ = 0).
# * Alternative Hypothesis (Ha): The drug decreases blood pressure (μ < 0).
# * Significance Level (α): 0.05
# * Calculation: t = (sample mean - hypothesized mean) / (sample standard deviation / √sample size)
# * t-statistic: t = (8 - 10) / (3 / √100) = -2.94
# * Degrees of Freedom: df = sample size - 1 = 99
# * p-value: p-value < 0.05 (one-tailed test)
# * Conclusion: Reject the null hypothesis; there is evidence that the drug decreases blood pressure.

# %% [markdown]
# #### Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.

# %% [markdown]
# * Null Hypothesis (H0): The true mean weight is equal to 5 pounds (μ = 5).
# * Alternative Hypothesis (Ha): The true mean weight is less than 5 pounds (μ < 5).
# * Significance Level (α): 0.01
# * Calculation: t = (sample mean - hypothesized mean) / (sample standard deviation / √sample size)
# * t-statistic: t = (4.8 - 5) / (0.5 / √25) = -2
# * Degrees of Freedom: df = sample size - 1 = 24
# * p-value: p-value < 0.01 (one-tailed test)
# * Conclusion: Reject the null hypothesis; there is evidence that the true mean weight is less than 5 pounds.

# %% [markdown]
# #### Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.

# %% [markdown]
# * Null Hypothesis (H0): The population means are equal (μ1 = μ2).
# * Alternative Hypothesis (Ha): The population means are not equal (μ1 ≠ μ2).
# * Significance Level (α): 0.01
# * Pooling Standard Deviations: Pooled standard deviation = √((s1^2 * (n1 - 1) + s2^2 * (n2 - 1)) / (n1 + n2 - 2))
# * Calculation: t = (sample mean difference - hypothesized mean difference) / (pooled standard deviation * √(1/n1 + 1/n2))
# * t-statistic: t = (80 - 75) / (pooled standard deviation * √(1/30 + 1/40))
# * Degrees of Freedom: df = n1 + n2 - 2 = 68
# * p-value: p-value < 0.01 (two-tailed test)
# * Conclusion: Reject the null hypothesis; there is evidence that the population means are not equal.

# %% [markdown]
# #### Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %% [markdown]
# * 99% Confidence Interval: Sample mean ± Margin of Error
# * Margin of Error: z * (sample standard deviation / √sample size)
# * Using z-score for 99% confidence interval: z = 2.576
# * Calculation: Margin of Error = 2.576 * (1.5 / √50) ≈ 0.54
# * Confidence Interval: 4 ± 0.54
# * Result: Population mean number of ads watched is estimated to be between 3.46 and 4.54.
